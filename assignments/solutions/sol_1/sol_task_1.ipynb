# %% [markdown]
# # Foglio Esercizi 3

# %%
import sol_task_1_utils as utils

# %% [markdown]
# ### Esercizio 1:
#
# *Scrivi una funzione che prende in input una stringa e stampa: tutta in maiuscolo, tutta in minuscolo, i singoli caratteri separati da uno spazio bianco.*
#
# > Memo: utilizza rispettivamente i metodi `upper()` e `lower()` forniti dal tipo stringa.
#
# > Memo: utilizza la flag `end=" "` della funzione `print` per lasciare uno spazio vuoto senza andare a capo.
#
# Esempio: f("Ciao")
# ```python
# Output:
# CIAO
# ciao
# C i a o
# ```

# %%
a = "Ciao! Come va?"
utils.fun_1(a)

# %% [markdown]
# ### Esercizio 2: scrivi una funzione che prende in input una stringa e ritorna il numero di parole.
#
# > Memo: utilizza il metodo `split` fornito dal tipo stringa

# %%
print(utils.conta_parole(a))

# %% [markdown]
# ### Esercizio 3: Scrivi una funzione che prende in input una striga e resituisce la lunghezza media delle parole che la compongono.

# %%
print(utils.fun_3(a))

# %% [markdown]
# ### Esercizio 4: Scrivi una funzione che converte un numero da decimale a binario

# %%
for i in range(16):
    print(str(utils.dec_to_bin(i)).zfill(4))

# %% [markdown]
# ### Esercizio 5: Scrivi una funione che dato un numero binario restituisce il corrispettivo numero in decimale

# %%
print(utils.bin_to_dec(1010))

# %% [markdown]
# ### Esercizio 6: Scrivi una funzione che prende in input una stringa e la riscrive in codifica ASCII come segue:
#
# ```
# f('Ciao')
# Output:
# C -> 01000011
# i -> 01101001
# a -> 01100001
# o -> 01101111
# ```
#
# > Memo: per stampare il numero con 8 carratteri convertilo in stringa e utilizza il metodo `zfill()` specificando tra parentesi il numero di cifre che deve raggiungere il numero.

# %%
utils.conv_to_ascii("Ciao")

# %% [markdown]
# ### Esercizio 7: Scrivi una funzione che prende in input una stringa in codifca ASCII e la riscrive con i caratteri corrispondenti

# %%
print(a)
a_ascii = utils.codifica_ascii(a)
print(a_ascii)

# %% [markdown]
# ### Esercizio 8: Decodifica

# %%
print(utils.decodifica_ascii(a_ascii))

# %% [markdown]
# ### Esercizio 8: Leggi un file di testo, converti ogni frase in codifica ASCII e salva il testo codificato in un nuovo file.

# %%
txt_path = "m1.txt"
with open(txt_path, "r") as f:
    messaggio = f.read()
print(messaggio)
messaggio_ascii = utils.codifica_ascii(messaggio)
print(messaggio_ascii)
ascii_path = "m1_ascii.txt"
with open(ascii_path, "w") as f:
    f.write(messaggio_ascii)

# %% [markdown]
# ### Esercizio 9: Leggi un file codificato e riscrivilo in un nuovo file decodificato.

# %%
ascii_path = "m2_ascii.txt"
with open(ascii_path, "r") as f:
    messaggio_letto = f.read()
print(messaggio_letto)
messaggio_tradotto = utils.decodifica_ascii(messaggio_letto)
print(messaggio_tradotto)
