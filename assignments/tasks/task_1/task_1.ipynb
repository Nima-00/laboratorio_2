# %% [markdown]
# # Foglio Esercizi 3

# %%
# import task_1_utils as utils

# %% [markdown]
# ### Esercizio 1:
#
# *Scrivi una funzione che prende in input una stringa e stampa: la stringa in maiuscolo, la stringa in minuscolo, i singoli caratteri separati da uno spazio bianco.*
#
# > Memo: utilizza rispettivamente i metodi `upper()` e `lower()` forniti dal tipo stringa.
#
# > Memo: utilizza la flag `end=" "` della funzione `print` per lasciare uno spazio vuoto senza andare a capo.
#
# Esempio: f("Ciao")
# ```python
# Output:
# CIAO
# ciao
# C i a o
# ```

# %% [markdown]
# ### Esercizio 2: scrivi una funzione che prende in input una stringa e ritorna il numero di parole di cui è composta.
#
# > Memo: utilizza il metodo `split()` fornito dal tipo stringa.

# %% [markdown]
# ### Esercizio 3: Scrivi una funzione che prende in input una stringa e resituisce la lunghezza media delle parole che la compongono.

# %% [markdown]
# ### Esercizio 4: Scrivi una funzione che converte un numero da decimale a binario

# %% [markdown]
# ### Esercizio 5: Scrivi una funione che converte un numero da binario a decimale

# %% [markdown]
# ### Esercizio 6: Scrivi una funzione che prende in input una stringa e la riscrive in codifica ASCII come segue:
#
# ```
# f('Ciao')
# Output:
# C -> 01000011
# i -> 01101001
# a -> 01100001
# o -> 01101111
# ```
#
# > Memo: la funzione ord() prende un carattere e resituisce il numero ASCII corrispondente come intero (es ord("A") -> 65). Per svolgere l'esercizio utilizza la funzione ord e converti il numero ottenuto in binario. Per stampare il numero con 8 carratteri convertilo in stringa e utilizza il metodo `zfill()` specificando tra parentesi il numero di cifre che deve raggiungere il numero.

# %% [markdown]
# ### Esercizio 7: Scrivi una funzione che prende in input una stringa in codifca ASCII e la riscrive con i caratteri corrispondenti

# %% [markdown]
# ### Esercizio 8: Leggi il file di testo m1.txt, convertilo in codifica ASCII e salva il testo codificato in un nuovo file m1_ascii.txt

# %% [markdown]
# ### Esercizio 9: Leggi il file m2_ascii.txt scritto come sequenza di caratteri ASCII, decodificalo, scrivi il risultato in un file m2.txt
