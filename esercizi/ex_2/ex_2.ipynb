# %% [markdown]
# # Foglio Esercizi 2

# %%
import ex_2_utils as utils

# %% [markdown]
# ### Esercizio 1 [1.25 pt]:
#
# *Scrivi una funzione che prende in input un numero intero e stampa gli elementi compresi tra 0 e n divisibili per 3.*
#
# Esempio: fun(12) -> 0, 3, 6, 9, 12

# %%
utils.fun_1(12)

# %% [markdown]
# ### Esercizio 2 [1.25 pt]:
#
# *Scrivi una funzione che prende in input una lista di interi e restituisce una nuova lista con gli elementi in ordine invertito.*
#
# Esempio: fun([1, 2, 3]) -> [3, 2, 1]

# %%
print(utils.fun_2([1, 2, 3]))

# %% [markdown]
# ### Esercizio 3 [1.5 pt]
#
# *Scrivi una funzione che prende in input una lista di interi `A` e un intero `num`. La funzione restituisce il numero di volte che `num` compare in `A`.*
#
# Esempio: fun([1, 2, 3, 4, 3, 4, 5], 4) -> 2

# %%
print(utils.fun_3([1, 2, 3, 2], 2))

# %% [markdown]
# ### Esercizio 4 [1.25 pt]:
#
# *Scrivi una funzione che prende in input una lista di numeri interi e restituisce il massimo valore presente nella lista.*
#
# Esempio: fun([1, -10, 3, 5]) -> 5

# %%
print(utils.fun_4([1,2 ,3, 50, 6]))

# %% [markdown]
# ### Esercizio 5 [1.25 pt]:
#
# *Scrivi una funzione che prende in input una lista di numeri interi $A=[x_0, \dots, x_{n-1}]$ e restituisce la lista normalizzata $[y_0, \dots, y_{n-1}]$ in cui ogni elemento è calcolato come segue:*
#
# $$
# y_i = \frac{e^{x_i}}{\sum_{i=0}^{n-1}e^{x_i}}
# $$
#
# >Memo: puoi approssimare il numero $e$ con $2.72$, oppure aggiungere `import math` all'inizio della cella e utilizzare `math.e`
#
# >Suggerimento: prima calcola $\sum_{i=0}^{n-1}e^{x_i}$, poi aggiorna ogni entrata della lista
#
# Esempio: fun([1, 1]) -> [0.5, 0.5]

# %%
print(utils.fun_5([1, 2, 2, 1]))

# %% [markdown]
# ### Esercizio 6 [1.5 pt]:
#
# *Scrivi una funzione che prende in input  un intero n e restituisce l'ennesimo termine della serie*
#
# $$
# s_1(n) = \sum_{i=1}^n \frac{1}{i^2}
# $$
#
# *Prova a stampare i primi 30 termini della serie. A che valore converge?*
#
# *Prova ora scrivere una nuova funzione che prende in input un intero n e restituisce l'n-simo termine di questa serie*
#
# $$
# s_2(n) = \sqrt{6 \cdot \sum_{i=1}^n \frac{1}{i^2}} = \sqrt{6 \cdot s_1(n)}
# $$
#
# *Prova a calcolare s_2(1000). Riconosci a che valore si avvicina questa seconda serie?*

# %%
for i in range(1, 31):
    print(f"{i}) {utils.fun_6(i)}")

# %%
print(utils.fun_7(1000))
