# %% [markdown]
# # Foglio Esercizi 1

# %%
import ex_1_utils as utils

# %% [markdown]
# ### Esercizio 1:
#
# *Scrivi una funzione che prende in input una lista `[m, q]`, rappresentante i coefficienti di una retta $y = mx + q$, e un valore float $x$.*
#
# *La funzione ritorna il valore della variabile $y$ valutata in $x$.*
#
# Esempio: fun((1, 0), 2) -> 2

# %%
# Esempio
c = [2.0, 3.0]  # m = 2, q = 3
x = 5.0
y = utils.fun_1(c, x)
print(y)  # Output: 13.0
# Out:
# 13.0

# %% [markdown]
# ### Esercizio 2:
#
# *Scrivi una funzione che prende in input una lista $[x_{min}, x_{max}]$ rappresentante gli estremi di un intervallo, e un numero intero $k$.*
#
# *La funzione divide l'intervallo $(x_{min}, x_{max})$ in $k$ sotto-intervalli e restituisce il valore degli estremi in ordine.*
#
# Esempio: fun((-1, 1), 2) -> [-1.0, 0.0, 1.0]

# %%
# Esempio
I = [-1.0, 1.0]
k = 2

x_punti = utils.fun_2(I, k)
print(x_punti)  # Output: [-1.0, 0.0, 1.0]
# Out:
# [-1.0, 0.0, 1.0]

# %% [markdown]
# ### Esercizio 3:
#
# *Scrivi una funzione che prende in input una lista $[m, q]$, rappresentante i coefficienti di una retta, e una lista di punti $[x_0, \dots, x_{n-1}]$.*
#
# *La funzione restituisce una lista $[y_0, \dots, y_{n-1}]$, dove $y_i = mx_i +q$.*

# %%
# Esempio
c = [2.0, 3.0]  # m = 2, q = 3
x_list = [-1.0, 0.0, 1.0]

y_list = utils.fun_3(c, x_list)
print(y_list)  # Output: [1.0, 3.0, 5.0]
# Out:
# [1.0, 3.0, 5.0]

# %% [markdown]
# ### Esercizio 4:
#
# *Utiliziamo la libreria `matplotlib` per disegnare il grafico della retta*

# %%
# Esempio
c = [1, 0]  # m = 2, q = 3
I = [-10.0, 10.0]
k = 8
fig_size = (5, 3)
utils.fun_4(c, I, k, fig_size)  # Output: [1.0, 3.0, 5.0]

# %%
de
